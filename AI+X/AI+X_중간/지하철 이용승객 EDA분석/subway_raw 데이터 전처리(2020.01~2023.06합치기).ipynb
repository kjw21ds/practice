# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
import os
os.chdir('drive/MyDrive/AI+X선도인재양성프로젝트/003.지하철 이용승객 EDA분석_숙제_20220914/실습')
# %load_ext autoreload
# %autoreload 2

# %%
# !ls
# Out:
# '1.지하철 이용승객 분석 EDA 프로젝트(1).ipynb'
# '2호선 역 승차 빈도(합계).html'
# 'AI+X기초프로젝트_실습(김정우, 2019).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2020).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2021).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2022).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2023).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2024).ipynb'
# 'AI+X연습(이상치를 평균으로 변환 후 주어진 문제들을 평균으로 구함).ipynb'
# 'AI+X연습(이상치를 평균으로 변환 후 주어진 문제들을 합계로 구함).ipynb'
# 'AI+X연습(총합(sum)으로 그래프 구함).ipynb'
# 'AI+X연습(평균으로 그래프 구함).ipynb'
#  rawfiles
#  rawfiles.zip
#  subway_raw.csv
# 'subway_raw 데이터 전처리(2020.01~2023.06합치기).ipynb'
# 'subway_raw 데이터 전처리.ipynb'
# 'subway_raw 데이터 전처리(연도 전체용).ipynb'
# '기온 데이터 전처리.ipynb'
# '일반휘발유와 지하철 승객 수의 상관관계_2017.ipynb'
# ...

# %%
import pandas as pd
raw_df = pd.read_csv('rawfiles/CARD_SUBWAY_MONTH_2023.csv')
raw_df
# Out:
#               사용일자 요일  노선명   역명  승차총승객수  하차총승객수  승하차총승객수       연월     월일
# 0       2023-01-01  일  1호선  동대문    8838    8509    17347  2023-01  01-01
# 1       2023-01-01  일  1호선  동묘앞    9982   10166    20148  2023-01  01-01
# 2       2023-01-01  일  1호선  서울역   31924   26931    58855  2023-01  01-01
# 3       2023-01-01  일  1호선   시청    9282    8253    17535  2023-01  01-01
# 4       2023-01-01  일  1호선  신설동    6317    6497    12814  2023-01  01-01
# ...            ... ..  ...  ...     ...     ...      ...      ...    ...
# 109856  2023-06-30  금  중앙선   원덕     374     402      776  2023-06  06-30
# 109857  2023-06-30  금  중앙선   중랑    6392    6044    12436  2023-06  06-30
# 109858  2023-06-30  금  중앙선   지평      52      84      136  2023-06  06-30
# 109859  2023-06-30  금  중앙선   팔당     938     979     1917  2023-06  06-30
# 109860  2023-06-30  금  중앙선   회기   28314   26277    54591  2023-06  06-30
#
# [109861 rows x 9 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18797 entries, 0 to 18796
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   사용일자    18797 non-null  int64
#  1   노선명     18797 non-null  object
#  2   역명      18797 non-null  object
#  3   승차총승객수  18797 non-null  int64
#  4   하차총승객수  18797 non-null  int64
#  5   등록일자    18797 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 881.2+ KB

# %%
raw_df = pd.DataFrame()
for i in range(0,3):
    temp_df = pd.read_csv(f'rawfiles/CARD_SUBWAY_MONTH(202{i}).csv')
    raw_df = pd.concat([raw_df, temp_df], axis=0)

raw_df = raw_df.reset_index(drop=True)
raw_df
# Out:
#               사용일자 요일  노선명   역명  승차총승객수  하차총승객수  승하차총승객수       연월     월일
# 0       2020-01-01  수  1호선  동대문    8822    9558    18380  2020-01  01-01
# 1       2020-01-01  수  1호선  동묘앞    7580    7998    15578  2020-01  01-01
# 2       2020-01-01  수  1호선  서울역   36470   29895    66365  2020-01  01-01
# 3       2020-01-01  수  1호선   시청   12126   10516    22642  2020-01  01-01
# 4       2020-01-01  수  1호선  신설동    6820    6589    13409  2020-01  01-01
# ...            ... ..  ...  ...     ...     ...      ...      ...    ...
# 656012  2022-12-31  토  중앙선   원덕     286     320      606  2022-12  12-31
# 656013  2022-12-31  토  중앙선   중랑    4223    3835     8058  2022-12  12-31
# 656014  2022-12-31  토  중앙선   지평      36      30       66  2022-12  12-31
# 656015  2022-12-31  토  중앙선   팔당     936    1088     2024  2022-12  12-31
# 656016  2022-12-31  토  중앙선   회기   18610   16269    34879  2022-12  12-31
#
# [656017 rows x 9 columns]

# %%
temp_df = pd.read_csv(f'rawfiles/CARD_SUBWAY_MONTH_2023.csv')
temp_df
# Out:
#               사용일자 요일  노선명   역명  승차총승객수  하차총승객수  승하차총승객수       연월     월일
# 0       2023-01-01  일  1호선  동대문    8838    8509    17347  2023-01  01-01
# 1       2023-01-01  일  1호선  동묘앞    9982   10166    20148  2023-01  01-01
# 2       2023-01-01  일  1호선  서울역   31924   26931    58855  2023-01  01-01
# 3       2023-01-01  일  1호선   시청    9282    8253    17535  2023-01  01-01
# 4       2023-01-01  일  1호선  신설동    6317    6497    12814  2023-01  01-01
# ...            ... ..  ...  ...     ...     ...      ...      ...    ...
# 109856  2023-06-30  금  중앙선   원덕     374     402      776  2023-06  06-30
# 109857  2023-06-30  금  중앙선   중랑    6392    6044    12436  2023-06  06-30
# 109858  2023-06-30  금  중앙선   지평      52      84      136  2023-06  06-30
# 109859  2023-06-30  금  중앙선   팔당     938     979     1917  2023-06  06-30
# 109860  2023-06-30  금  중앙선   회기   28314   26277    54591  2023-06  06-30
#
# [109861 rows x 9 columns]

# %%
raw_df = pd.concat([raw_df, temp_df], axis=0)
raw_df
# Out:
#               사용일자 요일  노선명   역명  승차총승객수  하차총승객수  승하차총승객수       연월     월일
# 0       2020-01-01  수  1호선  동대문    8822    9558    18380  2020-01  01-01
# 1       2020-01-01  수  1호선  동묘앞    7580    7998    15578  2020-01  01-01
# 2       2020-01-01  수  1호선  서울역   36470   29895    66365  2020-01  01-01
# 3       2020-01-01  수  1호선   시청   12126   10516    22642  2020-01  01-01
# 4       2020-01-01  수  1호선  신설동    6820    6589    13409  2020-01  01-01
# ...            ... ..  ...  ...     ...     ...      ...      ...    ...
# 109856  2023-06-30  금  중앙선   원덕     374     402      776  2023-06  06-30
# 109857  2023-06-30  금  중앙선   중랑    6392    6044    12436  2023-06  06-30
# 109858  2023-06-30  금  중앙선   지평      52      84      136  2023-06  06-30
# 109859  2023-06-30  금  중앙선   팔당     938     979     1917  2023-06  06-30
# 109860  2023-06-30  금  중앙선   회기   28314   26277    54591  2023-06  06-30
#
# [765878 rows x 9 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765878 entries, 0 to 109860
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   사용일자     765878 non-null  object
#  1   요일       765878 non-null  object
#  2   노선명      765878 non-null  object
#  3   역명       765878 non-null  object
#  4   승차총승객수   765878 non-null  int64
#  5   하차총승객수   765878 non-null  int64
#  6   승하차총승객수  765878 non-null  int64
#  7   연월       765878 non-null  object
#  8   월일       765878 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 58.4+ MB

# %%
raw_df['사용일자'] = pd.to_datetime(raw_df['사용일자'], format='%Y-%m-%d')
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 765878 entries, 0 to 109860
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   사용일자     765878 non-null  datetime64[ns]
#  1   요일       765878 non-null  object
#  2   노선명      765878 non-null  object
#  3   역명       765878 non-null  object
#  4   승차총승객수   765878 non-null  int64
#  5   하차총승객수   765878 non-null  int64
#  6   승하차총승객수  765878 non-null  int64
#  7   연월       765878 non-null  object
#  8   월일       765878 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(5)
# memory usage: 58.4+ MB

# %%
raw_df.isna().sum()
# Out:
# 사용일자       0
# 요일         0
# 노선명        0
# 역명         0
# 승차총승객수     0
# 하차총승객수     0
# 승하차총승객수    0
# 연월         0
# 월일         0
# dtype: int64

# %%
raw_df.duplicated(['사용일자','요일', '노선명', '역명', '연월', '월일'], keep=False).sum()
# Out:
# 0

# %%
raw_df.describe()
# Out:
#                                 사용일자         승차총승객수         하차총승객수  \
# count                         765878  765878.000000  765878.000000
# mean   2021-10-03 02:18:27.792102400    9707.295619    9672.998591
# min              2020-01-01 00:00:00       0.000000       0.000000
# 25%              2020-11-19 00:00:00    3218.000000    3115.000000
# 50%              2021-10-04 00:00:00    6827.000000    6666.000000
# 75%              2022-08-19 00:00:00   12765.000000   12583.000000
# max              2023-06-30 00:00:00  129997.000000  136864.000000
# std                              NaN    9894.544816   10030.862955
#
#              승하차총승객수
# count  765878.000000
# mean    19380.294210
# min         1.000000
# 25%      6350.000000
# 50%     13517.000000
# 75%     25336.000000
# max    266861.000000
# std     19896.560435

# %%
raw_df.describe(include='object')
# Out:
#             요일     노선명      역명       연월      월일
# count   765878  765878  765878   765878  765878
# unique       7      26     535       42     366
# top          목     5호선     서울역  2023-05   06-16
# freq    109796   69719    6385    18830    2412

# %%
raw_df
# Out:
#              사용일자 요일  노선명   역명  승차총승객수  하차총승객수  승하차총승객수       연월     월일
# 0      2020-01-01  수  1호선  동대문    8822    9558    18380  2020-01  01-01
# 1      2020-01-01  수  1호선  동묘앞    7580    7998    15578  2020-01  01-01
# 2      2020-01-01  수  1호선  서울역   36470   29895    66365  2020-01  01-01
# 3      2020-01-01  수  1호선   시청   12126   10516    22642  2020-01  01-01
# 4      2020-01-01  수  1호선  신설동    6820    6589    13409  2020-01  01-01
# ...           ... ..  ...  ...     ...     ...      ...      ...    ...
# 109856 2023-06-30  금  중앙선   원덕     374     402      776  2023-06  06-30
# 109857 2023-06-30  금  중앙선   중랑    6392    6044    12436  2023-06  06-30
# 109858 2023-06-30  금  중앙선   지평      52      84      136  2023-06  06-30
# 109859 2023-06-30  금  중앙선   팔당     938     979     1917  2023-06  06-30
# 109860 2023-06-30  금  중앙선   회기   28314   26277    54591  2023-06  06-30
#
# [765878 rows x 9 columns]

# %%
fpath = 'rawfiles/CARD_SUBWAY_MONTH(202001~202306).csv'
raw_df.to_csv(fpath, index=False, encoding='utf-8-sig')
