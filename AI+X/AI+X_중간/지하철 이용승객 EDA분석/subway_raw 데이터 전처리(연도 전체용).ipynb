# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
import os
os.chdir('drive/MyDrive/AI+X선도인재양성프로젝트/003.지하철 이용승객 EDA분석_숙제_20220914/실습')
# %load_ext autoreload
# %autoreload 2

# %%
# !ls
# Out:
# '1.지하철 이용승객 분석 EDA 프로젝트(1).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2018전체).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2019상반기).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2019 상반기 통계검정 포함).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2019전체).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2020전체).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2021전체).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2022전체).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2023전체).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 2024상반기).ipynb'
# 'AI+X기초프로젝트_실습(김정우, 통계검정 포함).ipynb'
# 'AI+X연습(이상치를 평균으로 변환 후 주어진 문제들을 평균으로 구함).ipynb'
# 'AI+X연습(이상치를 평균으로 변환 후 주어진 문제들을 합계로 구함).ipynb'
# 'AI+X연습(총합(sum)으로 그래프 구함).ipynb'
# 'AI+X연습(평균으로 그래프 구함).ipynb'
#  rawfiles
#  rawfiles.zip
#  subway_raw.csv
# 'subway_raw 데이터 전처리(2020.01~2023.06합치기).ipynb'
# 'subway_raw 데이터 전처리.ipynb'
# 'subway_raw 데이터 전처리(연도 전체용).ipynb'
# '코로나19 확진자수(서울) 데이터 전처리.ipynb'

# %%
# # 한글 깨짐 방지 위해 구글 코랩에 나눔폰트 설치.
# import sys
# if 'google.colab' in sys.modules:
#     !echo 'debconf debconf/frontend select Noninteractive' | debconf-set-selections
#     !sudo apt-get -qq -y install fonts-nanum
#     import matplotlib.font_manager as fm
#     font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])
#     for fpath in font_files:
#         fm.fontManager.addfont(fpath)

# %%
# # 나눔고딕으로 폰트 변경
# import matplotlib.pyplot as plt
# plt.rcParams['font.family'] = 'NanumGothic'

# %%
# # 만약 인코딩이 utf-8이 아니라면 변환 후 덮어쓰는 코드
# import pandas as pd
# import chardet

# # 파일 경로 설정
# original_file = f'rawfiles/CARD_SUBWAY_MONTH_2021.csv'

# # 파일의 현재 인코딩 확인
# with open(original_file, 'rb') as f:
#     result = chardet.detect(f.read())
# encoding = result['encoding']

# # 원본 파일을 읽고 UTF-8로 저장
# temp_df = pd.read_csv(original_file, encoding=encoding, on_bad_lines='skip')
# temp_df.to_csv(original_file, index=False, encoding='utf-8')

# %%
# import pandas as pd
# df = pd.read_csv('rawfiles/CARD_SUBWAY_MONTH_2021.csv', encoding='cp949', on_bad_lines='skip')

# %%
# df.to_csv('rawfiles/CARD_SUBWAY_MONTH_2021.csv', index=False, encoding='utf-8')

# %%
import pandas as pd
raw_df = pd.read_csv('rawfiles/CARD_SUBWAY_MONTH_2017.csv')   # csv파일이 어떻게 구성되어 있는지 확인
raw_df
# Out:
#             사용일자    노선명        역명   승차총승객수   하차총승객수      등록일자
# 0       20170101    2호선        봉천  11169.0  11198.0  20170109
# 1       20170101    2호선        신림  40137.0  42005.0  20170109
# 2       20170101    2호선       신대방  16033.0  16054.0  20170109
# 3       20170101    2호선   구로디지털단지  28246.0  28497.0  20170109
# 4       20170101    2호선  대림(구로구청)  20946.0  21926.0  20170109
# ...          ...    ...       ...      ...      ...       ...
# 208252  20171231    1호선      종로3가  27454.0  25522.0  20180103
# 208253  20171231    1호선        종각  42508.0  42903.0  20180103
# 208254  20171231    1호선        시청  17749.0  17461.0  20180103
# 208255  20171231    1호선       서울역  41637.0  42623.0  20180103
# 208256  20171231  우이신설선       신설동    913.0   1031.0  20180103
#
# [208257 rows x 6 columns]

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208257 entries, 0 to 208256
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사용일자    208257 non-null  int64
#  1   노선명     208257 non-null  object
#  2   역명      208257 non-null  object
#  3   승차총승객수  208257 non-null  float64
#  4   하차총승객수  208257 non-null  float64
#  5   등록일자    208257 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 9.5+ MB

# %%
# raw_df = pd.DataFrame()
# for year in [2017, 2018, 2019]:
#     temp_df = pd.read_csv(f'rawfiles/CARD_SUBWAY_MONTH_{year}.csv')
#     raw_df = pd.concat([raw_df, temp_df], axis=0)

# raw_df = raw_df.reset_index(drop=True)
# raw_df

# %%
raw_df['사용일자'] = pd.to_datetime(raw_df['사용일자'], format='%Y%m%d')
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208257 entries, 0 to 208256
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사용일자    208257 non-null  datetime64[ns]
#  1   노선명     208257 non-null  object
#  2   역명      208257 non-null  object
#  3   승차총승객수  208257 non-null  float64
#  4   하차총승객수  208257 non-null  float64
#  5   등록일자    208257 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 9.5+ MB

# %%
raw_df['요일'] = raw_df['사용일자'].dt.dayofweek
raw_df
# Out:
#              사용일자    노선명        역명   승차총승객수   하차총승객수      등록일자  요일
# 0      2017-01-01    2호선        봉천  11169.0  11198.0  20170109   6
# 1      2017-01-01    2호선        신림  40137.0  42005.0  20170109   6
# 2      2017-01-01    2호선       신대방  16033.0  16054.0  20170109   6
# 3      2017-01-01    2호선   구로디지털단지  28246.0  28497.0  20170109   6
# 4      2017-01-01    2호선  대림(구로구청)  20946.0  21926.0  20170109   6
# ...           ...    ...       ...      ...      ...       ...  ..
# 208252 2017-12-31    1호선      종로3가  27454.0  25522.0  20180103   6
# 208253 2017-12-31    1호선        종각  42508.0  42903.0  20180103   6
# 208254 2017-12-31    1호선        시청  17749.0  17461.0  20180103   6
# 208255 2017-12-31    1호선       서울역  41637.0  42623.0  20180103   6
# 208256 2017-12-31  우이신설선       신설동    913.0   1031.0  20180103   6
#
# [208257 rows x 7 columns]

# %%
day_of_week = {
    0 : '월',
    1 : '화',
    2 : '수',
    3 : '목',
    4 : '금',
    5 : '토',
    6 : '일'
}
raw_df['요일'] = raw_df['요일'].map(day_of_week)

# %%
raw_df['연월'] = raw_df['사용일자'].dt.strftime('%Y-%m')
raw_df['월일'] = raw_df['사용일자'].dt.strftime('%m-%d')
raw_df.head()
# Out:
#         사용일자  노선명        역명   승차총승객수   하차총승객수      등록일자 요일       연월     월일
# 0 2017-01-01  2호선        봉천  11169.0  11198.0  20170109  일  2017-01  01-01
# 1 2017-01-01  2호선        신림  40137.0  42005.0  20170109  일  2017-01  01-01
# 2 2017-01-01  2호선       신대방  16033.0  16054.0  20170109  일  2017-01  01-01
# 3 2017-01-01  2호선   구로디지털단지  28246.0  28497.0  20170109  일  2017-01  01-01
# 4 2017-01-01  2호선  대림(구로구청)  20946.0  21926.0  20170109  일  2017-01  01-01

# %%
raw_df['승하차총승객수'] = raw_df['승차총승객수'] + raw_df['하차총승객수']
raw_df.head()
# Out:
#         사용일자  노선명        역명   승차총승객수   하차총승객수      등록일자 요일       연월     월일  \
# 0 2017-01-01  2호선        봉천  11169.0  11198.0  20170109  일  2017-01  01-01
# 1 2017-01-01  2호선        신림  40137.0  42005.0  20170109  일  2017-01  01-01
# 2 2017-01-01  2호선       신대방  16033.0  16054.0  20170109  일  2017-01  01-01
# 3 2017-01-01  2호선   구로디지털단지  28246.0  28497.0  20170109  일  2017-01  01-01
# 4 2017-01-01  2호선  대림(구로구청)  20946.0  21926.0  20170109  일  2017-01  01-01
#
#    승하차총승객수
# 0  22367.0
# 1  82142.0
# 2  32087.0
# 3  56743.0
# 4  42872.0

# %%
raw_df.isna().sum()
# Out:
# 사용일자       0
# 노선명        0
# 역명         0
# 승차총승객수     0
# 하차총승객수     0
# 등록일자       0
# 요일         0
# 연월         0
# 월일         0
# 승하차총승객수    0
# dtype: int64

# %%
raw_df.duplicated(['사용일자','요일', '노선명', '역명', '연월', '월일'], keep=False).sum()
# Out:
# 22

# %%
raw_df[(raw_df['사용일자']=='2019-01-01') & (raw_df['역명']=='을지로4가')]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 등록일자, 요일, 연월, 월일, 승하차총승객수]
# Index: []

# %%
raw_df[(raw_df['사용일자']=='2019-01-01') & (raw_df['역명']=='서울역')]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 등록일자, 요일, 연월, 월일, 승하차총승객수]
# Index: []

# %%
raw_df[(raw_df['사용일자']=='2019-01-01') & (raw_df['역명']=='서울역')]
# Out:
# Empty DataFrame
# Columns: [사용일자, 노선명, 역명, 승차총승객수, 하차총승객수, 등록일자, 요일, 연월, 월일, 승하차총승객수]
# Index: []

# %%
raw_df = raw_df.groupby(['사용일자', '요일','노선명','역명','연월','월일', '등록일자']).sum().reset_index()

# %%
raw_df.duplicated(['사용일자','요일', '노선명', '역명', '연월', '월일'], keep=False).sum()
# Out:
# 0

# %%
raw_df[(raw_df['사용일자']=='2019-01-01') & (raw_df['역명']=='서울역')]
# Out:
# Empty DataFrame
# Columns: [사용일자, 요일, 노선명, 역명, 연월, 월일, 등록일자, 승차총승객수, 하차총승객수, 승하차총승객수]
# Index: []

# %%
raw_df = raw_df[['사용일자', '요일', '노선명', '역명', '승차총승객수', '하차총승객수', '승하차총승객수', '연월', '월일']]
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208246 entries, 0 to 208245
# Data columns (total 9 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   사용일자     208246 non-null  datetime64[ns]
#  1   요일       208246 non-null  object
#  2   노선명      208246 non-null  object
#  3   역명       208246 non-null  object
#  4   승차총승객수   208246 non-null  float64
#  5   하차총승객수   208246 non-null  float64
#  6   승하차총승객수  208246 non-null  float64
#  7   연월       208246 non-null  object
#  8   월일       208246 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 14.3+ MB

# %%
raw_df.describe()
# Out:
#                                 사용일자         승차총승객수         하차총승객수  \
# count                         208246  208246.000000  208246.000000
# mean   2017-07-03 00:11:27.894125312   12708.303891   12651.648723
# min              2017-01-01 00:00:00       1.000000       0.000000
# 25%              2017-04-03 00:00:00    4229.000000    4060.000000
# 50%              2017-07-03 00:00:00    8963.000000    8687.000000
# 75%              2017-10-03 00:00:00   16393.750000   16403.000000
# max              2017-12-31 00:00:00  152285.000000  143134.000000
# std                              NaN   13138.186100   13326.680472
#
#              승하차총승객수
# count  208246.000000
# mean    25359.952614
# min         1.000000
# 25%      8274.250000
# 50%     17640.000000
# 75%     32684.000000
# max    295419.000000
# std     26416.180197

# %%
raw_df.describe(include='object')
# Out:
#             요일     노선명      역명       연월      월일
# count   208246  208246  208246   208246  208246
# unique       7      25     503       12     365
# top          일     5호선     서울역  2017-12   12-07
# freq     30241   18615    1768    17987     582

# %%
raw_df
# Out:
#              사용일자 요일  노선명   역명   승차총승객수   하차총승객수  승하차총승객수       연월     월일
# 0      2017-01-01  일  1호선  동대문  12256.0  13775.0  26031.0  2017-01  01-01
# 1      2017-01-01  일  1호선  동묘앞  10197.0  10544.0  20741.0  2017-01  01-01
# 2      2017-01-01  일  1호선  서울역  43319.0  32946.0  76265.0  2017-01  01-01
# 3      2017-01-01  일  1호선   시청  10452.0   8299.0  18751.0  2017-01  01-01
# 4      2017-01-01  일  1호선  신설동   7721.0   7502.0  15223.0  2017-01  01-01
# ...           ... ..  ...  ...      ...      ...      ...      ...    ...
# 208241 2017-12-31  일  중앙선   원덕    324.0    387.0    711.0  2017-12  12-31
# 208242 2017-12-31  일  중앙선   중랑   4039.0   3687.0   7726.0  2017-12  12-31
# 208243 2017-12-31  일  중앙선   지평     23.0     27.0     50.0  2017-12  12-31
# 208244 2017-12-31  일  중앙선   팔당    894.0    937.0   1831.0  2017-12  12-31
# 208245 2017-12-31  일  중앙선   회기  19204.0  18442.0  37646.0  2017-12  12-31
#
# [208246 rows x 9 columns]

# %%
fpath = 'rawfiles/CARD_SUBWAY_MONTH(2017).csv'
raw_df.to_csv(fpath, index=False, encoding='utf-8-sig')
